# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

print("Dataset loaded!")
print(df.shape)
print(df.head())
print(df.columns)
# Out:
# Dataset loaded!
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

print("="*50)
print("DATASET INFO")
print("="*50)
print(f"Shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nData Types:\n{df.dtypes}")
print(f"\nMissing Values: {df.isnull().sum().sum()}")

print("\n" + "="*50)
print("BASIC STATISTICS")
print("="*50)
print(df.describe())

print("\n" + "="*50)
print("SPECIES COUNT")
print("="*50)
print(df['species'].value_counts())

print("\n" + "="*50)
print("AVERAGE MEASUREMENTS BY SPECIES")
print("="*50)
print(df.groupby('species')[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].mean())
# Out:
# ...
# DATASET INFO
# ...
# Shape: (150, 5)
#
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# Data Types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Missing Values: 0
#
# ...
# BASIC STATISTICS
# ...
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# ...
# SPECIES COUNT
# ...
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# ...

# %%
import pandas as pd

df_netflix = pd.read_csv("https://raw.githubusercontent.com/mdfahimabid/netflix-dataset/main/titles.csv")

print("="*50)
print("NETFLIX DATASET")
print("="*50)
print(f"Shape: {df_netflix.shape}")
print(f"\nColumns: {df_netflix.columns.tolist()}")
print(f"\nFirst 5 rows:")
print(df_netflix.head())

print("\n" + "="*50)
print("BASIC INFO")
print("="*50)
print(df_netflix.info())

print("\n" + "="*50)
print("MISSING VALUES")
print("="*50)
print(df_netflix.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_1364/2964133642.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df_netflix = pd.read_csv("https://raw.githubusercontent.com/mdfahimabid/netflix-dataset/main/titles.csv")
#       4
#       5 print("="*50)
#
# ...

# %%
import pandas as pd
import numpy as np

data = {
    'show_id': ['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8'],
    'title': ['Breaking Bad', 'The Crown', 'Stranger Things', 'DARK', 'Narcos', 'The Office', 'Friends', 'The Witcher'],
    'type': ['TV Show', 'TV Show', 'TV Show', 'TV Show', 'TV Show', 'TV Show', 'TV Show', 'TV Show'],
    'release_year': [2008, 2016, 2016, 2017, 2015, 2005, 1994, 2019],
    'country': ['United States', 'United Kingdom', 'United States', 'Germany', 'Colombia', 'United States', 'United States', 'Poland'],
    'duration': ['49 min', '58 min', '50 min', '55 min', '50 min', '22 min', '24 min', '60 min']
}

df_netflix = pd.DataFrame(data)

print("="*50)
print("NETFLIX ANALYSIS")
print("="*50)
print(f"Total Titles: {len(df_netflix)}")
print(f"\nMovies vs Shows:")
print(df_netflix['type'].value_counts())
print(f"\nRelease Year Range: {df_netflix['release_year'].min()} - {df_netflix['release_year'].max()}")
print(f"\nTop Countries:")
print(df_netflix['country'].value_counts())
print(f"\nDataset:")
print(df_netflix)
# Out:
# ...
# NETFLIX ANALYSIS
# ...
# Total Titles: 8
#
# Movies vs Shows:
# type
# TV Show    8
# Name: count, dtype: int64
#
# Release Year Range: 1994 - 2019
#
# Top Countries:
# country
# United States     4
# United Kingdom    1
# Germany           1
# Colombia          1
# Poland            1
# Name: count, dtype: int64
#
# Dataset:
#   show_id            title     type  release_year         country duration
# 0      s1     Breaking Bad  TV Show          2008   United States   49 min
# 1      s2        The Crown  TV Show          2016  United Kingdom   58 min
# 2      s3  Stranger Things  TV Show          2016   United States   50 min
# 3      s4             DARK  TV Show          2017         Germany   55 min
# 4      s5           Narcos  TV Show          2015        Colombia   50 min
# 5      s6       The Office  TV Show          2005   United States   22 min
# 6      s7          Friends  TV Show          1994   United States   24 min
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df_netflix['release_year'].hist(ax=axes[0], bins=10)
axes[0].set_title('Content by Year')
axes[0].set_xlabel('Year')

df_netflix['country'].value_counts().plot(kind='barh', ax=axes[1])
axes[1].set_title('Top Countries')

plt.tight_layout()
plt.show()
